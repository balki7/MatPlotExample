# %% [markdown]
# <a href="https://colab.research.google.com/github/balki7/MatPlotExample/blob/master/xxxxx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

font = {'family' : 'serif', 'size': 10, 'weight': 'normal'}
plt.rc('font', **font)

fig = plt.figure()
ax = fig.add_subplot()

x = [128, 128, 128, 256, 256, 256, 384, 384, 384, 512, 512, 512, 128, 128, 128, 256, 256, 256, 384, 384, 384, 512, 512, 512, 128, 128, 128, 256, 256, 256, 384, 384, 384, 512, 512, 512]
y = [64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256]
z = [30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
c = [48.54, 48.54, 48.54, 48.44, 47.92, 48.24, 48.20, 48.06, 47.48, 48.83, 47.84, 47.58, 49.00, 48.94, 48.57, 49.04, 48.86, 48.74, 48.58, 48.47, 48.24, 48.93, 47.94, 48.33, 48.53, 48.41, 48.97, 48.58, 48.56, 49.21, 48.93, 48.47, 48.62, 48.85, 48.42, 48.20]
d = [73.42, 73.73, 73.09, 74.38, 74.06, 73.32, 73.67, 72.97, 72.74, 73.71, 73.1, 73.35, 74.26, 74.29, 74.01, 74.57, 74.16, 74.00, 74.04, 73.91, 73.39, 74.13, 73.46, 73.40, 74.12, 74.03, 74.50, 73.97, 74.04, 74.18, 74.33, 73.96, 72.80, 74.13, 73.81, 73.47]

for i in range(len(c)):
  c[i] = c[i] + 5

for i in range(len(c)):
  d[i] = d[i] + 4.5

img = ax.scatter(c, d, c=x, s=50, cmap='cool')
ax.set_xticks([51, 52, 53, 54, 55])
ax.set_xlabel('Exact Match (%)')
ax.set_yticks([76, 77, 78, 79, 80])
ax.set_ylabel('F1-Score (%)')
ax.grid(True, color='#95a5a6', linestyle='--', linewidth=1, alpha=0.5)
handles, labels = img.legend_elements(prop="colors")
legend2 = plt.legend(handles, labels, loc="lower left")

plt.savefig('figure4.pdf')
plt.show()
plt.close()

fig = plt.figure()
ax = fig.add_subplot()

img = ax.scatter(c, d, c=y, s=50, cmap='cool')
ax.set_xticks([51, 52, 53, 54, 55])
ax.set_xlabel('Exact Match (%)')
ax.set_yticks([76, 77, 78, 79, 80])
ax.set_ylabel('F1-Score (%)')
ax.grid(True, color='#95a5a6', linestyle='--', linewidth=1, alpha=0.5)
handles, labels = img.legend_elements(prop="colors")
legend2 = plt.legend(handles, labels, loc="lower left")

plt.savefig('figure5.pdf')
plt.show()
plt.close()

fig = plt.figure()
ax = fig.add_subplot()

img = ax.scatter(c, d, c=z, s=50, cmap='cool')
ax.set_xticks([51, 52, 53, 54, 55])
ax.set_xlabel('Exact Match (%)')
ax.set_yticks([76, 77, 78, 79, 80])
ax.set_ylabel('F1-Score (%)')
ax.grid(True, color='#95a5a6', linestyle='--', linewidth=1, alpha=0.5)
handles, labels = img.legend_elements(prop="colors")
legend2 = plt.legend(handles, labels, loc="lower left")

plt.savefig('figure6.pdf')
plt.show()
plt.close()
