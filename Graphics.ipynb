# %% [markdown]
# <a href="https://colab.research.google.com/github/balki7/MatPlotExample/blob/master/Graphics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

font = {'family' : 'serif', 'size': 10, 'weight': 'normal'}
plt.rc('font', **font)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = [128, 128, 128, 256, 256, 256, 384, 384, 384, 512, 512, 512, 128, 128, 128, 256, 256, 256, 384, 384, 384, 512, 512, 512, 128, 128, 128, 256, 256, 256, 384, 384, 384, 512, 512, 512]
y = [64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256]
z = [32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
c = [48.54, 48.54, 48.54, 48.44, 47.92, 48.24, 48.20, 48.06, 47.48, 48.83, 47.84, 47.58, 49.00, 48.94, 48.57, 49.04, 48.86, 48.74, 48.58, 48.47, 48.24, 48.93, 47.94, 48.33, 48.53, 48.41, 48.97, 48.58, 48.56, 49.21, 48.93, 48.47, 48.62, 48.85, 48.42, 48.20]

img = ax.scatter(x, y, z, c=c, cmap=plt.cool())
fig.colorbar(img, pad=0.1)
ax.set_xticks([128, 256, 384, 512])
ax.set_xlabel('Doc Stride')
ax.set_yticks([64, 128, 256])
ax.set_ylabel('Max Query Length')
ax.set_zticks([32, 64, 128])
ax.set_zlabel('Max Answer Length')
ax.text(256, 64, 64, ' max', color='red') 
ax.grid(True)

plt.savefig('em_graph.pdf')
plt.show()
plt.close()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = [128, 128, 128, 256, 256, 256, 384, 384, 384, 512, 512, 512, 128, 128, 128, 256, 256, 256, 384, 384, 384, 512, 512, 512, 128, 128, 128, 256, 256, 256, 384, 384, 384, 512, 512, 512]
y = [64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256, 64, 128, 256]
z = [32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
c = [73.42, 73.73, 73.09, 74.38, 74.06, 73.32, 73.67, 72.97, 72.74, 73.71, 73.1, 73.35, 74.26, 74.29, 74.01, 74.57, 74.16, 74.00, 74.04, 73.91, 73.39, 74.13, 73.46, 73.40, 74.12, 74.03, 74.50, 73.97, 74.04, 74.18, 74.33, 73.96, 72.80, 74.13, 73.81, 73.47]

img = ax.scatter(x, y, z, c=c, cmap=plt.cool())
fig.colorbar(img, pad=0.1)
ax.set_xticks([128, 256, 384, 512])
ax.set_xlabel('Doc Stride')
ax.set_yticks([64, 128, 256])
ax.set_ylabel('Max Query Length')
ax.set_zticks([32, 64, 128])
ax.set_zlabel('Max Answer Length')
ax.text(256, 64, 64, ' max', color='red') 
ax.grid(True)

plt.savefig('f1_graph.pdf')
plt.show()
